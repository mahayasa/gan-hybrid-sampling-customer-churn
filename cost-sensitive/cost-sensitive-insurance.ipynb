# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

dataset=pd.read_csv('https://raw.githubusercontent.com/mahayasa/various-sampling-churn-prediction/main/data/insurance.csv')


X=dataset.drop(['labels'],axis=1)
y=dataset["labels"]

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
# define grid
balance = [{0:0,1:0},{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]
param_grid = dict(class_weight=balance)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.713424 using {'class_weight': {0: 100, 1: 1}}
# 0.500000 (0.000000) with: {'class_weight': {0: 0, 1: 0}}
# 0.713424 (0.008580) with: {'class_weight': {0: 100, 1: 1}}
# 0.711777 (0.011312) with: {'class_weight': {0: 10, 1: 1}}
# 0.700485 (0.008529) with: {'class_weight': {0: 1, 1: 1}}
# 0.680484 (0.006377) with: {'class_weight': {0: 1, 1: 10}}
# 0.672207 (0.008020) with: {'class_weight': {0: 1, 1: 100}}

# %%
from sklearn.metrics import f1_score, make_scorer
f1 = make_scorer(f1_score , average='macro')
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.702151 using {'class_weight': {0: 100, 1: 1}}
# 0.468935 (0.000019) with: {'class_weight': {0: 0, 1: 0}}
# 0.702151 (0.006864) with: {'class_weight': {0: 100, 1: 1}}
# 0.700060 (0.006391) with: {'class_weight': {0: 10, 1: 1}}
# 0.696658 (0.008891) with: {'class_weight': {0: 1, 1: 1}}
# 0.686078 (0.008094) with: {'class_weight': {0: 1, 1: 10}}
# 0.683215 (0.005268) with: {'class_weight': {0: 1, 1: 100}}

# %%
from imblearn.metrics import geometric_mean_score
gm_scorer = make_scorer(geometric_mean_score, greater_is_better=True, average='binary')

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.685087 using {'class_weight': {0: 100, 1: 1}}
# 0.000000 (0.000000) with: {'class_weight': {0: 0, 1: 0}}
# 0.685087 (0.009437) with: {'class_weight': {0: 100, 1: 1}}
# 0.680880 (0.011210) with: {'class_weight': {0: 10, 1: 1}}
# 0.663438 (0.012157) with: {'class_weight': {0: 1, 1: 1}}
# 0.631823 (0.012426) with: {'class_weight': {0: 1, 1: 10}}
# 0.619797 (0.008353) with: {'class_weight': {0: 1, 1: 100}}

# %%
# RF
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
# define grid
balance = [{0:0,1:0},{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]
param_grid = dict(class_weight=balance)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.925476 using {'class_weight': {0: 1, 1: 1}}
# 0.500000 (0.000000) with: {'class_weight': {0: 0, 1: 0}}
# 0.923849 (0.003773) with: {'class_weight': {0: 100, 1: 1}}
# 0.925018 (0.003452) with: {'class_weight': {0: 10, 1: 1}}
# 0.925476 (0.003680) with: {'class_weight': {0: 1, 1: 1}}
# 0.924809 (0.003996) with: {'class_weight': {0: 1, 1: 10}}
# 0.921096 (0.003819) with: {'class_weight': {0: 1, 1: 100}}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.741821 using {'class_weight': {0: 10, 1: 1}}
# 0.468935 (0.000019) with: {'class_weight': {0: 0, 1: 0}}
# 0.741448 (0.006756) with: {'class_weight': {0: 100, 1: 1}}
# 0.741821 (0.006349) with: {'class_weight': {0: 10, 1: 1}}
# 0.725692 (0.006110) with: {'class_weight': {0: 1, 1: 1}}
# 0.693390 (0.009292) with: {'class_weight': {0: 1, 1: 10}}
# 0.674805 (0.011175) with: {'class_weight': {0: 1, 1: 100}}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.669676 using {'class_weight': {0: 100, 1: 1}}
# 0.000000 (0.000000) with: {'class_weight': {0: 0, 1: 0}}
# 0.669676 (0.010191) with: {'class_weight': {0: 100, 1: 1}}
# 0.669206 (0.009376) with: {'class_weight': {0: 10, 1: 1}}
# 0.631391 (0.007845) with: {'class_weight': {0: 1, 1: 1}}
# 0.565511 (0.015255) with: {'class_weight': {0: 1, 1: 10}}
# 0.535466 (0.013057) with: {'class_weight': {0: 1, 1: 100}}

# %%
# LGB
from lightgbm import LGBMClassifier
model = LGBMClassifier()
# define grid
balance = [{0:0,1:0},{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]
param_grid = dict(class_weight=balance)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# [LightGBM] [Info] Number of positive: 3967, number of negative: 29941
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 987
# [LightGBM] [Info] Number of data points in the train set: 33908, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116993 -> initscore=-2.021219
# [LightGBM] [Info] Start training from score -2.021219
# Best: 0.933714 using {'class_weight': {0: 1, 1: 1}}
# 0.500000 (0.000000) with: {'class_weight': {0: 0, 1: 0}}
# 0.922631 (0.003824) with: {'class_weight': {0: 100, 1: 1}}
# 0.930281 (0.003464) with: {'class_weight': {0: 10, 1: 1}}
# 0.933714 (0.003001) with: {'class_weight': {0: 1, 1: 1}}
# 0.933349 (0.003700) with: {'class_weight': {0: 1, 1: 10}}
# 0.929612 (0.004349) with: {'class_weight': {0: 1, 1: 100}}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# [LightGBM] [Info] Number of positive: 3967, number of negative: 29941
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 987
# [LightGBM] [Info] Number of data points in the train set: 33908, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116993 -> initscore=-2.021219
# [LightGBM] [Info] Start training from score -2.021219
# Best: 0.750636 using {'class_weight': {0: 1, 1: 1}}
# 0.468935 (0.000019) with: {'class_weight': {0: 0, 1: 0}}
# 0.540177 (0.007193) with: {'class_weight': {0: 100, 1: 1}}
# 0.568823 (0.008452) with: {'class_weight': {0: 10, 1: 1}}
# 0.750636 (0.007641) with: {'class_weight': {0: 1, 1: 1}}
# 0.740651 (0.006589) with: {'class_weight': {0: 1, 1: 10}}
# 0.657070 (0.006139) with: {'class_weight': {0: 1, 1: 100}}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# [LightGBM] [Info] Number of positive: 3967, number of negative: 29941
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005947 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 987
# [LightGBM] [Info] Number of data points in the train set: 33908, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.569881 -> initscore=0.281366
# [LightGBM] [Info] Start training from score 0.281366
# Best: 0.865612 using {'class_weight': {0: 1, 1: 10}}
# 0.000000 (0.000000) with: {'class_weight': {0: 0, 1: 0}}
# 0.276847 (0.014929) with: {'class_weight': {0: 100, 1: 1}}
# 0.334093 (0.016231) with: {'class_weight': {0: 10, 1: 1}}
# 0.680809 (0.011775) with: {'class_weight': {0: 1, 1: 1}}
# 0.865612 (0.007370) with: {'class_weight': {0: 1, 1: 10}}
# 0.834994 (0.005605) with: {'class_weight': {0: 1, 1: 100}}

# %%
#XGB
from xgboost import XGBClassifier
model = XGBClassifier()
# define grid
weights = [1, 10, 25, 50, 75, 99, 100, 1000]
param_grid = dict(scale_pos_weight=weights)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.929161 using {'scale_pos_weight': 1}
# 0.929161 (0.003571) with: {'scale_pos_weight': 1}
# 0.924621 (0.004036) with: {'scale_pos_weight': 10}
# 0.921291 (0.004883) with: {'scale_pos_weight': 25}
# 0.919133 (0.005047) with: {'scale_pos_weight': 50}
# 0.917295 (0.005256) with: {'scale_pos_weight': 75}
# 0.915844 (0.005147) with: {'scale_pos_weight': 99}
# 0.916412 (0.005868) with: {'scale_pos_weight': 100}
# 0.910120 (0.005113) with: {'scale_pos_weight': 1000}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.761764 using {'scale_pos_weight': 10}
# 0.744273 (0.007063) with: {'scale_pos_weight': 1}
# 0.761764 (0.006347) with: {'scale_pos_weight': 10}
# 0.736158 (0.006291) with: {'scale_pos_weight': 25}
# 0.718753 (0.006720) with: {'scale_pos_weight': 50}
# 0.709088 (0.006754) with: {'scale_pos_weight': 75}
# 0.701847 (0.007117) with: {'scale_pos_weight': 99}
# 0.701228 (0.006180) with: {'scale_pos_weight': 100}
# 0.658311 (0.006959) with: {'scale_pos_weight': 1000}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.849242 using {'scale_pos_weight': 50}
# 0.678508 (0.012492) with: {'scale_pos_weight': 1}
# 0.843254 (0.008321) with: {'scale_pos_weight': 10}
# 0.849233 (0.008632) with: {'scale_pos_weight': 25}
# 0.849242 (0.007705) with: {'scale_pos_weight': 50}
# 0.846840 (0.007159) with: {'scale_pos_weight': 75}
# 0.844975 (0.008091) with: {'scale_pos_weight': 99}
# 0.844983 (0.007493) with: {'scale_pos_weight': 100}
# 0.825225 (0.006323) with: {'scale_pos_weight': 1000}
